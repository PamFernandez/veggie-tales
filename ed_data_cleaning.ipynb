# %%
import pandas as pd
from sklearn.preprocessing import normalize
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from pathlib import Path

# %%
file = Path('Resources/survey_results_1.xlsx')

# %%
results_df = pd.read_excel(file)
results_df.head()
# Out:
#    ID          Start time     Completion time      Email  Name  \
# 0   1 2022-06-04 15:01:02 2022-06-04 15:05:26  anonymous   NaN
# 1   2 2022-06-06 19:20:23 2022-06-06 19:22:18  anonymous   NaN
# 2   3 2022-06-06 19:19:21 2022-06-06 19:22:26  anonymous   NaN
# 3   4 2022-06-06 19:20:24 2022-06-06 19:25:18  anonymous   NaN
# 4   5 2022-06-06 19:28:42 2022-06-06 19:35:54  anonymous   NaN
#
#   What is your age range?  Gender Race/Ethnicity (Select all that apply)  \
# 0                   40-49  Female               Caucasian, non-Hispanic;
# 1                   20-29  Female                                 Asian;
# 2                   40-49  Female               Caucasian, non-Hispanic;
# 3                   20-29  Female             Black or African American;
# 4                   30-39  Female               Caucasian, non-Hispanic;
#
#   Which US Geographic Region do you live in?  \
# 0                                    Midwest
# 1                                    Midwest
# 2                                    Midwest
# 3                                    Midwest
# 4                                    Midwest
#
#   What is the name of your favorite TV Show?\n  \
# 0                                      Firefly
# 1                                     Vincenzo
# 2                                    Ted Lasso
# 3                                   Succession
# 4                                Critical Role
#
#   How often do you eat vegetables?  \
# 0                          1/week
# 1                         4-5/week
# 2                  Daily 6-7 week
# 3                         2-3/week
# 4                         2-3/week
#
#   Types of veggies you most like to eat (pick your top 5!)  \
# 0          Asparagus ;Corn;Carrots;Spinach;Broccoli;
# 1  Broccoli;Cauliflower;Corn;Green Beans;Peas;Spi...
# 2       Broccoli;Carrots;Green Beans;Spinach;Squash;
# 3     Broccoli;Carrots;Corn;Green Beans;Cauliflower;
# 4           Carrots;Spinach;Squash;Corn;Cauliflower;
#
#   What is your "go to" choice for veggies at home? (Pick your top three)  \
# 0                Lettuce (any kind);Carrots;Spinach;
# 1                                Broccoli;Corn;Peas;
# 2                           Broccoli;Carrots;Squash;
# 3                      Broccoli;Carrots;Cauliflower;
# 4                          Spinach;Carrots;Broccoli;
#
#   What is your "go to" choice for veggies at a restaurant (top three)  \
# 0                           Asparagus;Corn;Broccoli;
# 1                         Broccoli;Cauliflower;Corn;
# 2               Lettuce (any kind);Broccoli;Spinach;
# 3                      Broccoli;Carrots;Green Beans;
# 4                            Spinach;Carrots;Squash;
#
#   Preferred ways for cooking/preparing the choices you selected above  \
# 0                             Grilled;Sauteed;Baked;
# 1        Fried/Air-fried;Grilled;Sauteed;Microwaved;
# 2                                     Steamed;Baked;
# 3                     Baked;Fried/Air-fried;Steamed;
# 4                                     Baked;Sauteed;
#
#    What alternative to vegetables do you use/eat to stay healthy?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What are your top three favorite types of fruits you like to eat? (example: apples, bananas, oranges)
# 0                   Cherries, blueberries, pineapple
# 1                         Mangoes, cherries, oranges
# 2                      bananas, strawberries, mangos
# 3                     Bananas, strawberries, oranges
# 4                          Peaches, Oranges, Mangoes

# %%
#RENAME COLUMNS
survey_df = results_df.rename(columns={
    "ID":"id",
    "Start time": "start_time",
    "Completion time": "end_time",
    "Email": "email",
    "Name": "name",	
    "What is your age range?": "age",
    "Gender":"gender",	
    "Race/Ethnicity (Select all that apply)": "race",	
    "Which US Geographic Region do you live in?": "region",	
    "What is the name of your favorite TV Show?\n": "tv_show",
    "How often do you eat vegetables?": "frequency",
    "Types of veggies you most like to eat (pick your top 5!)": "to_eat",
    'What is your "go to" choice for veggies at home? (Pick your top three)': "at_home",
    'What is your "go to" choice for veggies at a restaurant (top three)': "at_restaurant",	
    "Preferred ways for cooking/preparing the choices you selected above": "cook_prep",
    "What alternative to vegetables do you use/eat to stay healthy?": "alternatives",
    "What are your top three favorite types of fruits you like to eat? (example: apples, bananas, oranges)": "fruits"})

# %%
#SPLIT COLUMNS WITH MULTIPLE SELECTIONS

to_eat_test = survey_df["to_eat"].str.split(';', expand=True)
drop_list_five = [0,1,2,3,4]
drop_list_three = [0,1,2]

top_to_eat = to_eat_test.drop(to_eat_test.columns.difference(drop_list_five), axis=1)


top_to_eat = top_to_eat.rename(columns={0:"to_eat_1", 1: "to_eat_2", 2: "to_eat_3", 3: "to_eat_4", 4: "to_eat_5"})
top_to_eat
# top_five = to_eat_test[[0,1,2,3,4]]
# top_five
# Out:
#        to_eat_1            to_eat_2     to_eat_3     to_eat_4  \
# 0    Asparagus                 Corn      Carrots      Spinach
# 1      Broccoli         Cauliflower         Corn  Green Beans
# 2      Broccoli             Carrots  Green Beans      Spinach
# 3      Broccoli             Carrots         Corn  Green Beans
# 4       Carrots             Spinach       Squash         Corn
# ..          ...                 ...          ...          ...
# 170        Corn            Broccoli  Cauliflower      Carrots
# 171    Broccoli             Carrots  Green Beans
# 172        Corn  Lettuce (any kind)      Spinach      Carrots
# 173     Carrots             Spinach     Broccoli  Cauliflower
# 174        Peas            Broccoli      Carrots  Cauliflower
#
#                to_eat_5
# 0              Broccoli
# 1                  Peas
# 2                Squash
# 3           Cauliflower
# 4           Cauliflower
# ..                  ...
# 170
# 171                None
# 172
# 173         Green Beans
# 174  Lettuce (any kind)
#
# [175 rows x 5 columns]

# %%
# survey_df['to_eat_'{i+1}'] = top_to_eat[i]
# survey_df

# %%
survey_df["tv_show"] = survey_df["tv_show"].str.upper()
survey_df
# Out:
#       id          start_time            end_time      email  name    age  \
# 0      1 2022-06-04 15:01:02 2022-06-04 15:05:26  anonymous   NaN  40-49
# 1      2 2022-06-06 19:20:23 2022-06-06 19:22:18  anonymous   NaN  20-29
# 2      3 2022-06-06 19:19:21 2022-06-06 19:22:26  anonymous   NaN  40-49
# 3      4 2022-06-06 19:20:24 2022-06-06 19:25:18  anonymous   NaN  20-29
# 4      5 2022-06-06 19:28:42 2022-06-06 19:35:54  anonymous   NaN  30-39
# ..   ...                 ...                 ...        ...   ...    ...
# 170  171 2022-06-08 07:22:36 2022-06-08 07:25:52  anonymous   NaN  50-65
# 171  172 2022-06-08 08:45:06 2022-06-08 08:47:29  anonymous   NaN  40-49
# 172  173 2022-06-08 08:47:55 2022-06-08 08:50:06  anonymous   NaN  40-49
# 173  174 2022-06-08 21:35:14 2022-06-08 21:38:54  anonymous   NaN  50-65
# 174  175 2022-06-10 08:37:10 2022-06-10 08:39:49  anonymous   NaN  50-65
#
#      gender                         race   region         tv_show  \
# 0    Female     Caucasian, non-Hispanic;  Midwest         FIREFLY
# 1    Female                       Asian;  Midwest        VINCENZO
# 2    Female     Caucasian, non-Hispanic;  Midwest       TED LASSO
# 3    Female   Black or African American;  Midwest      SUCCESSION
# 4    Female     Caucasian, non-Hispanic;  Midwest   CRITICAL ROLE
# ..      ...                          ...      ...             ...
# 170  Female     Caucasian, non-Hispanic;  Midwest         CHOPPED
# 171    Male  Caucasian, Latino/Hispanic;  Midwest       SEINFELD
# 172  Female     Caucasian, non-Hispanic;  Midwest  DON'T HAVE ONE
# 173  Female     Caucasian, non-Hispanic;  Midwest    JIMMY KIMMEL
# 174  Female     Caucasian, non-Hispanic;  Midwest      60 MINUTES
#
#                                              frequency  \
# 0                                              1/week
# 1                                             4-5/week
# 2                                      Daily 6-7 week
# 3                                             2-3/week
# 4                                             2-3/week
# ..                                                 ...
# 170                                           2-3/week
# 171                                           4-5/week
# 172  Rarely (Only if someone makes me; holidays onl...
# 173                                           4-5/week
# 174                                    Daily 6-7 week
#
#                                                 to_eat  \
# 0            Asparagus ;Corn;Carrots;Spinach;Broccoli;
# 1    Broccoli;Cauliflower;Corn;Green Beans;Peas;Spi...
# 2         Broccoli;Carrots;Green Beans;Spinach;Squash;
# 3       Broccoli;Carrots;Corn;Green Beans;Cauliflower;
# 4             Carrots;Spinach;Squash;Corn;Cauliflower;
# ..                                                 ...
# 170                 Corn;Broccoli;Cauliflower;Carrots;
# 171                      Broccoli;Carrots;Green Beans;
# 172           Corn;Lettuce (any kind);Spinach;Carrots;
# 173  Carrots;Spinach;Broccoli;Cauliflower;Green Beans;
# 174  Peas;Broccoli;Carrots;Cauliflower;Lettuce (any...
#
#                                  at_home  \
# 0    Lettuce (any kind);Carrots;Spinach;
# 1                    Broccoli;Corn;Peas;
# 2               Broccoli;Carrots;Squash;
# 3          Broccoli;Carrots;Cauliflower;
# 4              Spinach;Carrots;Broccoli;
# ..                                   ...
# 170                       Corn;Broccoli;
# 171                            Broccoli;
# 172     Carrots;Corn;Lettuce (any kind);
# 173            Carrots;Spinach;Broccoli;
# 174               Peas;Broccoli;Carrots;
#
#                             at_restaurant  \
# 0                Asparagus;Corn;Broccoli;
# 1              Broccoli;Cauliflower;Corn;
# 2    Lettuce (any kind);Broccoli;Spinach;
# 3           Broccoli;Carrots;Green Beans;
# 4                 Spinach;Carrots;Squash;
# ..                                    ...
# 170     Corn;Broccoli;Lettuce (any kind);
# 171                   Lettuce (any kind);
# 172                                 Corn;
# 173         Broccoli;Cauliflower;Spinach;
# 174              Peas;Squash;Cauliflower;
#
#                                        cook_prep  alternatives  \
# 0                         Grilled;Sauteed;Baked;           NaN
# 1    Fried/Air-fried;Grilled;Sauteed;Microwaved;           NaN
# 2                                 Steamed;Baked;           NaN
# 3                 Baked;Fried/Air-fried;Steamed;           NaN
# 4                                 Baked;Sauteed;           NaN
# ..                                           ...           ...
# 170                                       Baked;           NaN
# 171                                  Microwaved;           NaN
# 172                                     Steamed;           NaN
# 173                                     Sauteed;           NaN
# 174                       Baked;Grilled;Steamed;           NaN
#
#                                fruits
# 0    Cherries, blueberries, pineapple
# 1          Mangoes, cherries, oranges
# 2       bananas, strawberries, mangos
# 3      Bananas, strawberries, oranges
# 4           Peaches, Oranges, Mangoes
# ..                                ...
# 170                         Blueberry
# 171    Bananas, strawberries, kumquat
# 172         Kiwi, mango, strawberries
# 173        Bananna's, apples, oranges
# 174    Blueberries, peaches, cherries
#
# [175 rows x 17 columns]

# %%
drop_list_five = [0,1,2,3,4]
drop_list_three = [0,1,2]

# SPLIT COLUMNS WITH MULTIPLE SELECTIONS
survey1_df = to_eat_test = survey_df["to_eat"].str.split(';', expand = True)
at_home_test = survey_df["at_home"].str.split(';', expand = True)
at_restaurant_test = survey_df["at_restaurant"].str.split(';', expand = True)
cook_prep_test = survey_df["cook_prep"].str.split(';', expand = True)
fruits_test = survey_df["fruits"].str.split(',', expand = True)

# drop any columns that come after our drop list
top_to_eat = to_eat_test.drop(to_eat_test.columns.difference(drop_list_five), axis = 1)
top_at_home = at_home_test.drop(at_home_test.columns.difference(drop_list_three), axis = 1)
top_at_restaurant = at_restaurant_test.drop(at_restaurant_test.columns.difference(drop_list_three), axis = 1)
top_cook_prep = cook_prep_test.drop(cook_prep_test.columns.difference(drop_list_three), axis = 1)
top_fruits = fruits_test.drop(fruits_test.columns.difference(drop_list_three), axis = 1)

# rename the new columns
top_to_eat = top_to_eat.rename(columns = {0:"to_eat_1", 1: "to_eat_2", 2: "to_eat_3", 3: "to_eat_4", 4: "to_eat_5"})
top_at_home = top_at_home.rename(columns = {0:"at_home_1", 1: "at_home_2", 2: "at_home_3"})
top_at_restaurant = top_at_restaurant.rename(columns = {0:"at_restaurant_1", 1: "at_restaurant_2", 2: "at_restaurant_3"})
top_cook_prep = top_cook_prep.rename(columns = {0:"cook_prep_1", 1: "cook_prep_2", 2: "cook_prep_3"})
top_fruits = top_fruits.rename(columns = {0:"fruits_1", 1: "fruits_2", 2: "fruits_3"})

# %%
top_fruits
# Out:
#         fruits_1       fruits_2       fruits_3
# 0       Cherries    blueberries      pineapple
# 1        Mangoes       cherries        oranges
# 2        bananas   strawberries         mangos
# 3        Bananas   strawberries        oranges
# 4        Peaches        Oranges        Mangoes
# ..           ...            ...            ...
# 170    Blueberry           None           None
# 171      Bananas   strawberries        kumquat
# 172         Kiwi          mango   strawberries
# 173    Bananna's         apples        oranges
# 174  Blueberries        peaches       cherries
#
# [175 rows x 3 columns]

# %%
#Creating list of new dataframes
df_list = [top_to_eat, top_at_home, top_at_restaurant,top_cook_prep, top_fruits]
# pd.merge(pd.merge(top_to_eat,top_at_home,on='id'),top_at_restaurant,on='id')

#Merging new dataframes into one
df = df_list[0]
for df_ in df_list[1:]:
    df = df.merge(df_, left_index=True, right_index=True)

#Adding columns back into survey_df 
for column in df:
     
    # Select column conents by column
    # name using [] operator
    survey_df[column] = df[column]

print(survey_df.keys())
# Out:
# Index(['id', 'start_time', 'end_time', 'email', 'name', 'age', 'gender',
#        'race', 'region', 'tv_show', 'frequency', 'to_eat', 'at_home',
#        'at_restaurant', 'cook_prep', 'alternatives', 'fruits', 'to_eat_1',
#        'to_eat_2', 'to_eat_3', 'to_eat_4', 'to_eat_5', 'at_home_1',
#        'at_home_2', 'at_home_3', 'at_restaurant_1', 'at_restaurant_2',
#        'at_restaurant_3', 'cook_prep_1', 'cook_prep_2', 'cook_prep_3',
#        'fruits_1', 'fruits_2', 'fruits_3'],
#       dtype='object')

# %%
#Dependencies for API
import requests
import json

from api_key import movie_api

# %%
shows = survey_df["tv_show"].tolist()
print(shows)
# Out:
# ['FIREFLY', 'VINCENZO', 'TED LASSO', 'SUCCESSION', 'CRITICAL ROLE', 'GOSSIP GIRL', 'DEMON SLAYER', 'WEST WING', 'FRIENDS', 'NCIS', 'NCIS', 'THE OFFICE', 'TOP CHEF', 'OUTLANDER', 'NEW GIRL', 'TWIN PEAKS', 'STRANGER THINGS', 'NONE', 'CHICAGO MED', 'NEW GIRL', 'BATTLEBOTS', 'BREAKING BAD', 'FAMILY FEUD ', 'CHICAGO MED, FIRE, PD', 'THE OFFICE', 'RICK AND MORTY', "HELL'S KITCHEN ", 'BOB’S BURGERS', 'THIS IS US', 'SPORTS', 'DANCING WITH THE STARS', 'HOW I MET YOUR MOTHER', 'GREY’S ANATOMY ', 'OUR FLAG MEANS DEATH', 'CHICAGO SERIES', 'FRIENDS', 'HANNIBAL', 'STRANGER THINGS', 'NOVA', 'CHICAGO FIRE', 'THE BOYS', 'THE OFFICE', "SCHITT'S CREEK", 'STAR TREK ', 'THE OFFICE', 'MONDAY NIGHT FOOTBALL ', 'CHICAGO PD', 'BLACKLIST', 'STATION ELEVEN', 'THE FIRST LADY', 'JEOPARDY ', 'HGTV SHOWS', 'WALKING DEAD', 'YOU', 'ALL AMERICAN ', 'COSBY SHOW', 'STRANGER THINGS', 'THE L WORD', 'THE WIRE', 'FIREFLY', "I DON'T HAVE ONE", 'THE SIMPSONS', 'SUPERNATURAL', 'FRIENDS ', 'JANE THE VIRGIN ', 'DATELINE', 'STRANGER THINGS', 'SEINFELD', 'THE SAPRANOS', "I DON'T HAVE ONE ", 'HANDMAIDS TALE', 'THE CHASE', 'SHERLOCK', 'CALL THE MIDWIFE', 'WHAT WE DO IN THE SHADOWS ', 'OFFICE', 'GREYS ANATOMY', 'GHOST', 'SPY X FAMILY', 'OWL HOUSE', 'CHICAGO FIRE', 'EVERYONE LOVES RAYMOND', 'THE GOOD PLACE', 'NCIS', 'THIS IS US', 'TED LASSO', 'MILWAUKEE BREWERS PREGAME', 'THE OFFICE', 'JEOPARDY ', 'ARRESTED DEVELOPMENT', 'BELOW DECK', 'THE NEWS', 'THE OFFICE', 'JEOPARDY ', 'SCHITT’S CREEK', 'THE WEST WING', 'OZARK', 'SCHITT’S CREEK', 'THE OFFICE', 'CARIBBEAN LIFE', 'HEARTLAND ', 'EUPHORIA', 'GRAYS ANATOMY ', 'FUTURAMA', 'LAW AND ORDER SVU', 'CASTLE ', 'STARGATE', 'THIS IS US', 'PSYCH', 'NO CURRENT FAVORITE', 'HOUSEWIVES', 'THE BOYS', 'OZARKS', 'SOUTH PARK', 'GRAYS ANATOMY ', 'BELOW DECK', 'THE CBS MORNING SHOW', "GREY'S ANATOMY", 'GREY’S ANATOMY ', 'NCIS', 'GREYS ANATOMY', 'THIS IS US', 'RIGHT NOW STANGERS THINGS', 'EUPHORIA', 'SATURDAY NIGHT LIVE', 'NONE', 'QUEEN OF THE SOUTH ', 'THE OFFICE', 'TED LASSO', 'LAW AND ORDER', 'DATELINE', 'OUR FLAG MEANS DEATH', 'THE REAL HOUSEWIVES OF BEVERLY HILLS', 'ARRESTED DEVELOPMENT', 'AVATAR THE LAST AIR BENDER', 'FRIENDS', 'SEINFELD', 'BLUE BLOODS ', 'SCORPIANS', 'THIS IS US', '30 ROCK', 'NEW GIRL', 'NAILED IT ', 'I DON’T HAVE ONE ', 'ROCK THE PARK, PET RESCUE', 'MONK', 'NO SPECIFIC SHOW - I LIKE MURDER MYSTERIES, FOOD NETWORK CHAMPIONSHIP COOKING CONTESTS, ROM-COMS, ETC.  ', 'THE GREAT BRITISH BAKE-OFF', 'BLUE BLOODS', 'THE OFFICE', 'I DON’T WATCH TV', 'SURVIVOR ', 'NONE', 'SELLING SUNSET', 'CHICAGO PD', 'A MILLION LITTLE THINGS', '90 DAY FIANCE', 'GILMORE GIRLS ', 'CHICAGO FIRE', 'BONES', 'SHETLAND', 'STRANGER THINGS', 'FIREFLY', 'OUTLANDER', 'BULL', 'GAME OF THRONES', 'GRACE AND FRANKIE ', 'OBI-WAN KENOBI', 'GENERAL HOSPITAL ', 'HIS DARK MATERIALS ', 'CHOPPED', 'SEINFELD ', "DON'T HAVE ONE", 'JIMMY KIMMEL', '60 MINUTES']

# %%
tv_url = "https://api.themoviedb.org/3/search/tv?api_key="+movie_api

ids = []
titles = []
genre_id = []
test = []
broken = []

for tv in shows:
    search = requests.get(tv_url + "&query="+tv).json()
    # search = requests.get(movie_url + "&query= CRITICAL ROLE").json()
    try:
        tv_id = search['results'][0]['id']
        titles.append(tv)
            
    except:
        broken.append(tv)
        print(f"'{tv}' failed again")
# Out:
# 'CHICAGO MED, FIRE, PD' failed again
# 'CHICAGO SERIES' failed again
# 'HGTV SHOWS' failed again
# 'I DON'T HAVE ONE' failed again
# 'THE SAPRANOS' failed again
# 'I DON'T HAVE ONE ' failed again
# 'EVERYONE LOVES RAYMOND' failed again
# 'MILWAUKEE BREWERS PREGAME' failed again
# 'GRAYS ANATOMY ' failed again
# 'NO CURRENT FAVORITE' failed again
# 'GRAYS ANATOMY ' failed again
# 'THE CBS MORNING SHOW' failed again
# 'RIGHT NOW STANGERS THINGS' failed again
# 'AVATAR THE LAST AIR BENDER' failed again
# 'SCORPIANS' failed again
# 'I DON’T HAVE ONE ' failed again
# 'ROCK THE PARK, PET RESCUE' failed again
# 'NO SPECIFIC SHOW - I LIKE MURDER MYSTERIES, FOOD NETWORK CHAMPIONSHIP COOKING CONTESTS, ROM-COMS, ETC.  ' failed again
# 'DON'T HAVE ONE' failed again

# %%
# REPLACING TYPOS AND RESULTS THAT WERE NOT A SINGLE SHOW
survey_df["tv_show"] = survey_df["tv_show"].replace(['CHICAGO MED, FIRE, PD', 'CHICAGO SERIES'],['CHICAGO MED','CHICAGO MED'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['HGTV SHOWS'],['FIXER UPPER'])
survey_df["tv_show"] = survey_df["tv_show"].replace(["I DON'T HAVE ONE","I DON’T HAVE ONE "],['NONE','NONE'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['THE SAPRANOS'],['THE SOPRANOS'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['EVERYONE LOVES RAYMOND'],['EVERYBODY LOVES RAYMOND'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['MILWAUKEE BREWERS PREGAME'],['THURSDAY NIGHT BASEBALL'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['NO CURRENT FAVORITE'],['NONE'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['GRAYS ANATOMY '],["GREY'S ANATOMY"])
survey_df["tv_show"] = survey_df["tv_show"].replace(['THE CBS MORNING SHOW'],['CBS MORNING NEWS'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['RIGHT NOW STANGERS THINGS'],['STRANGER THINGS'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['AVATAR THE LAST AIR BENDER'],['AVATAR: THE LAST AIRBENDER'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['SCORPIANS'],['SCORPION'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['ROCK THE PARK, PET RESCUE'],['ROCK THE PARK'])
survey_df["tv_show"] = survey_df["tv_show"].replace(['NO SPECIFIC SHOW - I LIKE MURDER MYSTERIES, FOOD NETWORK CHAMPIONSHIP COOKING CONTESTS, ROM-COMS, ETC.  '],['THE AFTER PARTY'])
survey_df["tv_show"] = survey_df["tv_show"].replace(["DON'T HAVE ONE"],['NONE'])
shows = survey_df["tv_show"].to_list()
print(shows)
# Out:
# ['FIREFLY', 'VINCENZO', 'TED LASSO', 'SUCCESSION', 'CRITICAL ROLE', 'GOSSIP GIRL', 'DEMON SLAYER', 'WEST WING', 'FRIENDS', 'NCIS', 'NCIS', 'THE OFFICE', 'TOP CHEF', 'OUTLANDER', 'NEW GIRL', 'TWIN PEAKS', 'STRANGER THINGS', 'NONE', 'CHICAGO MED', 'NEW GIRL', 'BATTLEBOTS', 'BREAKING BAD', 'FAMILY FEUD ', 'CHICAGO MED', 'THE OFFICE', 'RICK AND MORTY', "HELL'S KITCHEN ", 'BOB’S BURGERS', 'THIS IS US', 'SPORTS', 'DANCING WITH THE STARS', 'HOW I MET YOUR MOTHER', 'GREY’S ANATOMY ', 'OUR FLAG MEANS DEATH', 'CHICAGO MED', 'FRIENDS', 'HANNIBAL', 'STRANGER THINGS', 'NOVA', 'CHICAGO FIRE', 'THE BOYS', 'THE OFFICE', "SCHITT'S CREEK", 'STAR TREK ', 'THE OFFICE', 'MONDAY NIGHT FOOTBALL ', 'CHICAGO PD', 'BLACKLIST', 'STATION ELEVEN', 'THE FIRST LADY', 'JEOPARDY ', 'FIXER UPPER', 'WALKING DEAD', 'YOU', 'ALL AMERICAN ', 'COSBY SHOW', 'STRANGER THINGS', 'THE L WORD', 'THE WIRE', 'FIREFLY', 'NONE', 'THE SIMPSONS', 'SUPERNATURAL', 'FRIENDS ', 'JANE THE VIRGIN ', 'DATELINE', 'STRANGER THINGS', 'SEINFELD', 'THE SOPRANOS', 'NONE', 'HANDMAIDS TALE', 'THE CHASE', 'SHERLOCK', 'CALL THE MIDWIFE', 'WHAT WE DO IN THE SHADOWS ', 'OFFICE', 'GREYS ANATOMY', 'GHOST', 'SPY X FAMILY', 'OWL HOUSE', 'CHICAGO FIRE', 'EVERYBODY LOVES RAYMOND', 'THE GOOD PLACE', 'NCIS', 'THIS IS US', 'TED LASSO', 'THURSDAY NIGHT BASEBALL', 'THE OFFICE', 'JEOPARDY ', 'ARRESTED DEVELOPMENT', 'BELOW DECK', 'THE NEWS', 'THE OFFICE', 'JEOPARDY ', 'SCHITT’S CREEK', 'THE WEST WING', 'OZARK', 'SCHITT’S CREEK', 'THE OFFICE', 'CARIBBEAN LIFE', 'HEARTLAND ', 'EUPHORIA', "GREY'S ANATOMY", 'FUTURAMA', 'LAW AND ORDER SVU', 'CASTLE ', 'STARGATE', 'THIS IS US', 'PSYCH', 'NONE', 'HOUSEWIVES', 'THE BOYS', 'OZARKS', 'SOUTH PARK', "GREY'S ANATOMY", 'BELOW DECK', 'CBS MORNING NEWS', "GREY'S ANATOMY", 'GREY’S ANATOMY ', 'NCIS', 'GREYS ANATOMY', 'THIS IS US', 'STRANGER THINGS', 'EUPHORIA', 'SATURDAY NIGHT LIVE', 'NONE', 'QUEEN OF THE SOUTH ', 'THE OFFICE', 'TED LASSO', 'LAW AND ORDER', 'DATELINE', 'OUR FLAG MEANS DEATH', 'THE REAL HOUSEWIVES OF BEVERLY HILLS', 'ARRESTED DEVELOPMENT', 'AVATAR: THE LAST AIRBENDER', 'FRIENDS', 'SEINFELD', 'BLUE BLOODS ', 'SCORPION', 'THIS IS US', '30 ROCK', 'NEW GIRL', 'NAILED IT ', 'NONE', 'ROCK THE PARK', 'MONK', 'THE AFTER PARTY', 'THE GREAT BRITISH BAKE-OFF', 'BLUE BLOODS', 'THE OFFICE', 'I DON’T WATCH TV', 'SURVIVOR ', 'NONE', 'SELLING SUNSET', 'CHICAGO PD', 'A MILLION LITTLE THINGS', '90 DAY FIANCE', 'GILMORE GIRLS ', 'CHICAGO FIRE', 'BONES', 'SHETLAND', 'STRANGER THINGS', 'FIREFLY', 'OUTLANDER', 'BULL', 'GAME OF THRONES', 'GRACE AND FRANKIE ', 'OBI-WAN KENOBI', 'GENERAL HOSPITAL ', 'HIS DARK MATERIALS ', 'CHOPPED', 'SEINFELD ', 'NONE', 'JIMMY KIMMEL', '60 MINUTES']

# %%
tv_url = "https://api.themoviedb.org/3/search/tv?api_key="+movie_api

ids = []
titles = []
genre_id = []
test = []
broken = []
for tv in shows:
    search = requests.get(tv_url + "&query="+tv).json()
    # search = requests.get(movie_url + "&query= CRITICAL ROLE").json()
    try:
        tv_id = search['results'][0]['id']
        titles.append(tv)
            
    except:
        broken.append(tv)
        print(f"'{tv}' failed again")
